# %%
import matplotlib.pyplot as plt
import seaborn as sb
import pandas as pd
import numpy as np
from sklearn.datasets import load_iris

# %%
iris = load_iris()

X = iris.data
y = iris.target
feature_names = iris.feature_names
target_names = iris.target_names

df = pd.DataFrame(X, columns=feature_names)
df['target'] = y
df['species'] = df['target'].map({i: name for i, name in enumerate(target_names)})
iris = df
print(iris)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target    species
# 0         0     setosa
# 1         0     setosa
# 2         0     setosa
# 3         0     setosa
# 4         0     setosa
# ..      ...        ...
# 145       2  virginica
# 146       2  virginica
# 147       2  virginica
# 148       2  virginica
# 149       2  virginica
#
# [150 rows x 6 columns]

# %%
print(iris.shape)
print(iris.columns)
print(iris["species"].value_counts())
# Out:
# (150, 6)
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)', 'target', 'species'],
#       dtype='object')
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
sb.set_style('whitegrid')
g = sb.FacetGrid(iris, hue='species', height=4)
g.map(plt.scatter, 'sepal length (cm)', 'sepal width (cm)')
g.add_legend()

plt.show()

# %%
plt.close()
sb.set_style("whitegrid")
sb.pairplot(iris, hue="species", size=2)
plt.show()
# Out:
# c:\Users\yash9\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\axisgrid.py:2100: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
